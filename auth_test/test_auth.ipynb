# %%
import time
import json
import os
from dotenv import load_dotenv
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# https://spotipy.readthedocs.io/en/2.16.1/

# %%
load_dotenv()

SPOTIPY_CLIENT_ID  = os.getenv("CLIENT_ID")
SPOTIPY_CLIENT_SECRET  = os.getenv("CLIENT_SECRET")
scope = "user-read-recently-played"
REDIRECT_URI = "http://127.0.0.1:8239/callback"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET, redirect_uri=REDIRECT_URI))
results = sp.current_user_recently_played(limit=1)

# %%
results = sp.current_user_recently_played(limit=50)

# %%
results
# Out:
# {'items': [{'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#        'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#        'id': '0ZbgKh0FgPYeFP38nVaEGp',
#        'name': 'Obito',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#        'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#        'id': '3hRnvEdu1iPyB6EzMBbuZq',
#        'name': 'Shiki',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03ZYR4zwCrkSsXTROnK2d0'},
#      'href': 'https://api.spotify.com/v1/albums/03ZYR4zwCrkSsXTROnK2d0',
#      'id': '03ZYR4zwCrkSsXTROnK2d0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a06a6b51d0dc296d48505ee6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a06a6b51d0dc296d48505ee6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a06a6b51d0dc296d48505ee6',
#        'width': 64}],
#      'name': 'Đánh Đổi',
#      'release_date': '2023-10-10',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:03ZYR4zwCrkSsXTROnK2d0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#       'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#       'id': '3hRnvEdu1iPyB6EzMBbuZq',
#       'name': 'Shiki',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EOMdQwzUG6CKh9oWvcANr'},
#       'href': 'https://api.spotify.com/v1/artists/0EOMdQwzUG6CKh9oWvcANr',
#       'id': '0EOMdQwzUG6CKh9oWvcANr',
#       'name': 'Lăng LD',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EOMdQwzUG6CKh9oWvcANr'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 184615,
#     'explicit': True,
#     'external_ids': {'isrc': 'DGA0M2366808'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2G5ujw3rrWcAXQqT8PVnrz'},
#     'href': 'https://api.spotify.com/v1/tracks/2G5ujw3rrWcAXQqT8PVnrz',
#     'id': '2G5ujw3rrWcAXQqT8PVnrz',
#     'is_local': False,
#     'name': 'Đầu Đường Xó Chợ',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2G5ujw3rrWcAXQqT8PVnrz'},
#    'played_at': '2025-04-18T04:17:58.729Z',
#    'context': {'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#     'type': 'artist',
#     'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#        'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#        'id': '0ZbgKh0FgPYeFP38nVaEGp',
#        'name': 'Obito',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#        'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#        'id': '3hRnvEdu1iPyB6EzMBbuZq',
#        'name': 'Shiki',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03ZYR4zwCrkSsXTROnK2d0'},
#      'href': 'https://api.spotify.com/v1/albums/03ZYR4zwCrkSsXTROnK2d0',
#      'id': '03ZYR4zwCrkSsXTROnK2d0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a06a6b51d0dc296d48505ee6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a06a6b51d0dc296d48505ee6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a06a6b51d0dc296d48505ee6',
#        'width': 64}],
#      'name': 'Đánh Đổi',
#      'release_date': '2023-10-10',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:03ZYR4zwCrkSsXTROnK2d0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#       'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#       'id': '3hRnvEdu1iPyB6EzMBbuZq',
#       'name': 'Shiki',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224175,
#     'explicit': True,
#     'external_ids': {'isrc': 'DGA0M2366818'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Asy51yFMEG8Qjh15kvQeD'},
#     'href': 'https://api.spotify.com/v1/tracks/2Asy51yFMEG8Qjh15kvQeD',
#     'id': '2Asy51yFMEG8Qjh15kvQeD',
#     'is_local': False,
#     'name': 'Tell the kids i love them',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:2Asy51yFMEG8Qjh15kvQeD'},
#    'played_at': '2025-04-18T04:06:36.133Z',
#    'context': {'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#     'type': 'artist',
#     'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22MX8BG5870DGzpNricY7q'},
#        'href': 'https://api.spotify.com/v1/artists/22MX8BG5870DGzpNricY7q',
#        'id': '22MX8BG5870DGzpNricY7q',
#        'name': 'VSOUL',
#        'type': 'artist',
#        'uri': 'spotify:artist:22MX8BG5870DGzpNricY7q'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5DUq1RazriMLxB7eKmcWdR'},
#      'href': 'https://api.spotify.com/v1/albums/5DUq1RazriMLxB7eKmcWdR',
#      'id': '5DUq1RazriMLxB7eKmcWdR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f10bf8a14d0bb7d6c20632b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f10bf8a14d0bb7d6c20632b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f10bf8a14d0bb7d6c20632b',
#        'width': 64}],
#      'name': 'Buồn Hay Vui (feat. RPT MCK, Obito, Ronboogz & Boyzed)',
#      'release_date': '2023-12-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5DUq1RazriMLxB7eKmcWdR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22MX8BG5870DGzpNricY7q'},
#       'href': 'https://api.spotify.com/v1/artists/22MX8BG5870DGzpNricY7q',
#       'id': '22MX8BG5870DGzpNricY7q',
#       'name': 'VSOUL',
#       'type': 'artist',
#       'uri': 'spotify:artist:22MX8BG5870DGzpNricY7q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zSv9qZANOWB4HRE8sxeTL'},
#       'href': 'https://api.spotify.com/v1/artists/1zSv9qZANOWB4HRE8sxeTL',
#       'id': '1zSv9qZANOWB4HRE8sxeTL',
#       'name': 'RPT MCK',
#       'type': 'artist',
#       'uri': 'spotify:artist:1zSv9qZANOWB4HRE8sxeTL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0dBcEvEklr1jx4uZuhFX5e'},
#       'href': 'https://api.spotify.com/v1/artists/0dBcEvEklr1jx4uZuhFX5e',
#       'id': '0dBcEvEklr1jx4uZuhFX5e',
#       'name': 'Ronboogz',
#       'type': 'artist',
#       'uri': 'spotify:artist:0dBcEvEklr1jx4uZuhFX5e'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JPTuJJ7KzpwcDCOWkEjUb'},
#       'href': 'https://api.spotify.com/v1/artists/1JPTuJJ7KzpwcDCOWkEjUb',
#       'id': '1JPTuJJ7KzpwcDCOWkEjUb',
#       'name': 'Boyzed',
#       'type': 'artist',
#       'uri': 'spotify:artist:1JPTuJJ7KzpwcDCOWkEjUb'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 291750,
#     'explicit': False,
#     'external_ids': {'isrc': 'DGA0R2314994'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4OXAneZHFJyQV1RuzCzmH3'},
#     'href': 'https://api.spotify.com/v1/tracks/4OXAneZHFJyQV1RuzCzmH3',
#     'id': '4OXAneZHFJyQV1RuzCzmH3',
#     'is_local': False,
#     'name': 'Buồn Hay Vui (feat. RPT MCK, Obito, Ronboogz & Boyzed)',
#     'popularity': 64,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4OXAneZHFJyQV1RuzCzmH3'},
#    'played_at': '2025-04-18T04:02:51.512Z',
#    'context': {'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#     'type': 'artist',
#     'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#        'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#        'id': '0ZbgKh0FgPYeFP38nVaEGp',
#        'name': 'Obito',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#        'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#        'id': '3hRnvEdu1iPyB6EzMBbuZq',
#        'name': 'Shiki',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03ZYR4zwCrkSsXTROnK2d0'},
#      'href': 'https://api.spotify.com/v1/albums/03ZYR4zwCrkSsXTROnK2d0',
#      'id': '03ZYR4zwCrkSsXTROnK2d0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a06a6b51d0dc296d48505ee6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a06a6b51d0dc296d48505ee6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a06a6b51d0dc296d48505ee6',
#        'width': 64}],
#      'name': 'Đánh Đổi',
#      'release_date': '2023-10-10',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:03ZYR4zwCrkSsXTROnK2d0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#       'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#       'id': '3hRnvEdu1iPyB6EzMBbuZq',
#       'name': 'Shiki',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zSv9qZANOWB4HRE8sxeTL'},
#       'href': 'https://api.spotify.com/v1/artists/1zSv9qZANOWB4HRE8sxeTL',
#       'id': '1zSv9qZANOWB4HRE8sxeTL',
#       'name': 'RPT MCK',
#       'type': 'artist',
#       'uri': 'spotify:artist:1zSv9qZANOWB4HRE8sxeTL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 226993,
#     'explicit': True,
#     'external_ids': {'isrc': 'DGA0M2366816'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UQNU5O9VttUgO16pxUnjw'},
#     'href': 'https://api.spotify.com/v1/tracks/1UQNU5O9VttUgO16pxUnjw',
#     'id': '1UQNU5O9VttUgO16pxUnjw',
#     'is_local': False,
#     'name': 'Đánh Đổi',
#     'popularity': 65,
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:1UQNU5O9VttUgO16pxUnjw'},
#    'played_at': '2025-04-18T03:57:56.764Z',
#    'context': {'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#     'type': 'artist',
#     'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04xz9bIBYTIqEpmRvQkfvu'},
#        'href': 'https://api.spotify.com/v1/artists/04xz9bIBYTIqEpmRvQkfvu',
#        'id': '04xz9bIBYTIqEpmRvQkfvu',
#        'name': 'Tyronee',
#        'type': 'artist',
#        'uri': 'spotify:artist:04xz9bIBYTIqEpmRvQkfvu'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1FbMoGXodZzHVcFhSK4pUu'},
#      'href': 'https://api.spotify.com/v1/albums/1FbMoGXodZzHVcFhSK4pUu',
#      'id': '1FbMoGXodZzHVcFhSK4pUu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a171ee2a43aa3a81be396e80',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a171ee2a43aa3a81be396e80',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a171ee2a43aa3a81be396e80',
#        'width': 64}],
#      'name': 'ii-V-I',
#      'release_date': '2024-12-05',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:1FbMoGXodZzHVcFhSK4pUu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04xz9bIBYTIqEpmRvQkfvu'},
#       'href': 'https://api.spotify.com/v1/artists/04xz9bIBYTIqEpmRvQkfvu',
#       'id': '04xz9bIBYTIqEpmRvQkfvu',
#       'name': 'Tyronee',
#       'type': 'artist',
#       'uri': 'spotify:artist:04xz9bIBYTIqEpmRvQkfvu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2aMo0CYbTieTisS0BlWc59'},
#       'href': 'https://api.spotify.com/v1/artists/2aMo0CYbTieTisS0BlWc59',
#       'id': '2aMo0CYbTieTisS0BlWc59',
#       'name': 'VSTRA',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aMo0CYbTieTisS0BlWc59'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 165161,
#     'explicit': False,
#     'external_ids': {'isrc': 'US38Y2432508'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72NMPuJCRsOUoXQJdzVfdo'},
#     'href': 'https://api.spotify.com/v1/tracks/72NMPuJCRsOUoXQJdzVfdo',
#     'id': '72NMPuJCRsOUoXQJdzVfdo',
#     'is_local': False,
#     'name': 'Track 06',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:72NMPuJCRsOUoXQJdzVfdo'},
#    'played_at': '2025-04-18T03:53:48.556Z',
#    'context': {'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#     'type': 'artist',
#     'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#        'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#        'id': '3hRnvEdu1iPyB6EzMBbuZq',
#        'name': 'Shiki',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1P7wZAMsCTQtRBdlEsStWN'},
#      'href': 'https://api.spotify.com/v1/albums/1P7wZAMsCTQtRBdlEsStWN',
#      'id': '1P7wZAMsCTQtRBdlEsStWN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c353169a2288f403265ee402',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c353169a2288f403265ee402',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c353169a2288f403265ee402',
#        'width': 64}],
#      'name': 'Lặng',
#      'release_date': '2024-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:1P7wZAMsCTQtRBdlEsStWN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hRnvEdu1iPyB6EzMBbuZq'},
#       'href': 'https://api.spotify.com/v1/artists/3hRnvEdu1iPyB6EzMBbuZq',
#       'id': '3hRnvEdu1iPyB6EzMBbuZq',
#       'name': 'Shiki',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hRnvEdu1iPyB6EzMBbuZq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 152000,
#     'explicit': False,
#     'external_ids': {'isrc': 'US38Y2414636'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5XfGQZA0ioQAWUjlyJRcHc'},
#     'href': 'https://api.spotify.com/v1/tracks/5XfGQZA0ioQAWUjlyJRcHc',
#     'id': '5XfGQZA0ioQAWUjlyJRcHc',
#     'is_local': False,
#     'name': '1000 Ánh Mắt',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5XfGQZA0ioQAWUjlyJRcHc'},
#    'played_at': '2025-04-18T03:51:02.982Z',
#    'context': {'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#     'type': 'artist',
#     'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#        'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#        'id': '0ZbgKh0FgPYeFP38nVaEGp',
#        'name': 'Obito',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ptD1JJgSXmsTtiRlv4JQu'},
#      'href': 'https://api.spotify.com/v1/albums/4ptD1JJgSXmsTtiRlv4JQu',
#      'id': '4ptD1JJgSXmsTtiRlv4JQu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c148fc776e64492cfa2881ee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c148fc776e64492cfa2881ee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c148fc776e64492cfa2881ee',
#        'width': 64}],
#      'name': 'thap trap tu do (remix)',
#      'release_date': '2025-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4ptD1JJgSXmsTtiRlv4JQu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZbgKh0FgPYeFP38nVaEGp'},
#       'href': 'https://api.spotify.com/v1/artists/0ZbgKh0FgPYeFP38nVaEGp',
#       'id': '0ZbgKh0FgPYeFP38nVaEGp',
#       'name': 'Obito',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZbgKh0FgPYeFP38nVaEGp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
# ...
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 190600,
#     'explicit': False,
#     'external_ids': {'isrc': 'BGA471804536'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54w3CUwFmj02KNZMuK1Cwn'},
#     'href': 'https://api.spotify.com/v1/tracks/54w3CUwFmj02KNZMuK1Cwn',
#     'id': '54w3CUwFmj02KNZMuK1Cwn',
#     'is_local': False,
#     'name': 'Cho',
#     'popularity': 52,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:54w3CUwFmj02KNZMuK1Cwn'},
#    'played_at': '2025-04-17T11:02:19.297Z',
#    'context': {'href': 'https://api.spotify.com/v1/albums/5A8HQs5og9i3Z4f4zyWqBC',
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5A8HQs5og9i3Z4f4zyWqBC'},
#     'type': 'album',
#     'uri': 'spotify:album:5A8HQs5og9i3Z4f4zyWqBC'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TdtsDVivxc6PpkQdNuXdR'},
#        'href': 'https://api.spotify.com/v1/artists/1TdtsDVivxc6PpkQdNuXdR',
#        'id': '1TdtsDVivxc6PpkQdNuXdR',
#        'name': 'Tùng',
#        'type': 'artist',
#        'uri': 'spotify:artist:1TdtsDVivxc6PpkQdNuXdR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5A8HQs5og9i3Z4f4zyWqBC'},
#      'href': 'https://api.spotify.com/v1/albums/5A8HQs5og9i3Z4f4zyWqBC',
#      'id': '5A8HQs5og9i3Z4f4zyWqBC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27344ece835e08da288f5643617',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0244ece835e08da288f5643617',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485144ece835e08da288f5643617',
#        'width': 64}],
#      'name': 'ĐỂ LEO MỘT NGỌN NÚI',
#      'release_date': '2025-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5A8HQs5og9i3Z4f4zyWqBC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TdtsDVivxc6PpkQdNuXdR'},
#       'href': 'https://api.spotify.com/v1/artists/1TdtsDVivxc6PpkQdNuXdR',
#       'id': '1TdtsDVivxc6PpkQdNuXdR',
#       'name': 'Tùng',
#       'type': 'artist',
#       'uri': 'spotify:artist:1TdtsDVivxc6PpkQdNuXdR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 360000,
#     'explicit': False,
#     'external_ids': {'isrc': 'VNA1M2404256'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3lHvw2f0PBIbJZVOA37Tkx'},
#     'href': 'https://api.spotify.com/v1/tracks/3lHvw2f0PBIbJZVOA37Tkx',
#     'id': '3lHvw2f0PBIbJZVOA37Tkx',
#     'is_local': False,
#     'name': 'Để Leo Một Ngọn Núi',
#     'popularity': 38,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3lHvw2f0PBIbJZVOA37Tkx'},
#    'played_at': '2025-04-17T10:44:54.182Z',
#    'context': {'href': 'https://api.spotify.com/v1/albums/5A8HQs5og9i3Z4f4zyWqBC',
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5A8HQs5og9i3Z4f4zyWqBC'},
#     'type': 'album',
#     'uri': 'spotify:album:5A8HQs5og9i3Z4f4zyWqBC'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TdtsDVivxc6PpkQdNuXdR'},
#        'href': 'https://api.spotify.com/v1/artists/1TdtsDVivxc6PpkQdNuXdR',
#        'id': '1TdtsDVivxc6PpkQdNuXdR',
#        'name': 'Tùng',
#        'type': 'artist',
#        'uri': 'spotify:artist:1TdtsDVivxc6PpkQdNuXdR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5A8HQs5og9i3Z4f4zyWqBC'},
#      'href': 'https://api.spotify.com/v1/albums/5A8HQs5og9i3Z4f4zyWqBC',
#      'id': '5A8HQs5og9i3Z4f4zyWqBC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27344ece835e08da288f5643617',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0244ece835e08da288f5643617',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485144ece835e08da288f5643617',
#        'width': 64}],
#      'name': 'ĐỂ LEO MỘT NGỌN NÚI',
#      'release_date': '2025-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5A8HQs5og9i3Z4f4zyWqBC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TdtsDVivxc6PpkQdNuXdR'},
#       'href': 'https://api.spotify.com/v1/artists/1TdtsDVivxc6PpkQdNuXdR',
#       'id': '1TdtsDVivxc6PpkQdNuXdR',
#       'name': 'Tùng',
#       'type': 'artist',
#       'uri': 'spotify:artist:1TdtsDVivxc6PpkQdNuXdR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 360000,
#     'explicit': False,
#     'external_ids': {'isrc': 'VNA1M2404256'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3lHvw2f0PBIbJZVOA37Tkx'},
#     'href': 'https://api.spotify.com/v1/tracks/3lHvw2f0PBIbJZVOA37Tkx',
#     'id': '3lHvw2f0PBIbJZVOA37Tkx',
#     'is_local': False,
#     'name': 'Để Leo Một Ngọn Núi',
#     'popularity': 38,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3lHvw2f0PBIbJZVOA37Tkx'},
#    'played_at': '2025-04-17T08:29:35.110Z',
#    'context': {'href': 'https://api.spotify.com/v1/albums/5A8HQs5og9i3Z4f4zyWqBC',
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5A8HQs5og9i3Z4f4zyWqBC'},
#     'type': 'album',
#     'uri': 'spotify:album:5A8HQs5og9i3Z4f4zyWqBC'}}],
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?before=1744878575110&limit=50',
#  'cursors': {'after': '1744949878729', 'before': '1744878575110'},
#  'limit': 50,
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?limit=50'}
